# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('previsao_de_renda.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             15000 non-null  int64
#  1   data_ref               15000 non-null  object
#  2   index                  15000 non-null  int64
#  3   sexo                   15000 non-null  object
#  4   posse_de_veiculo       15000 non-null  bool
#  5   posse_de_imovel        15000 non-null  bool
#  6   qtd_filhos             15000 non-null  int64
#  7   tipo_renda             15000 non-null  object
#  8   educacao               15000 non-null  object
#  9   estado_civil           15000 non-null  object
#  10  tipo_residencia        15000 non-null  object
#  11  idade                  15000 non-null  int64
#  12  tempo_emprego          12466 non-null  float64
#  13  qt_pessoas_residencia  15000 non-null  float64
# ...

# %%
df['data_ref'] = pd.to_datetime(df['data_ref'])
df.dtypes
# Out:
# Unnamed: 0                        int64
# data_ref                 datetime64[ns]
# index                             int64
# sexo                             object
# posse_de_veiculo                   bool
# posse_de_imovel                    bool
# qtd_filhos                        int64
# tipo_renda                       object
# educacao                         object
# estado_civil                     object
# tipo_residencia                  object
# idade                             int64
# tempo_emprego                   float64
# qt_pessoas_residencia           float64
# mau                                bool
# renda                           float64
# dtype: object

# %%
plt.figure(figsize=(15,4))

ax = sns.countplot(x='data_ref', hue='sexo', data=df)

tick_labs = df['data_ref'].map(lambda ts: ts.strftime("%m-%Y")).unique()

ticks = ax.set_xticks(list(range(df['data_ref'].nunique())))
labels = ax.set_xticklabels(tick_labs)

plt.legend(bbox_to_anchor = (1.05, 1), loc = 2, borderaxespad = 0);

# %%
plt.figure(figsize=(15,6))

ax = sns.countplot(x='data_ref', hue='posse_de_veiculo', data=df)

labels = ax.set_xticklabels(tick_labs)

plt.legend(bbox_to_anchor = (1.05, 1), loc = 2, borderaxespad = 0);

# %%
plt.figure(figsize=(15,6))

ax = sns.countplot(x='data_ref', hue='posse_de_imovel', data=df)

labels = ax.set_xticklabels(tick_labs)

plt.legend(bbox_to_anchor = (1.05, 1), loc = 2, borderaxespad = 0);

# %%
plt.figure(figsize=(15,6))

ax = sns.countplot(x='data_ref', hue='tipo_renda', data=df)

labels = ax.set_xticklabels(tick_labs)

plt.legend(bbox_to_anchor = (1.05, 1), loc = 2, borderaxespad = 0);

# %%
plt.figure(figsize=(15,6))

ax = sns.countplot(x='data_ref', hue='educacao', data=df)

labels = ax.set_xticklabels(tick_labs)

plt.legend(bbox_to_anchor = (1.05, 1), loc = 2, borderaxespad = 0);

# %%
plt.figure(figsize=(15,6))

ax = sns.countplot(x='data_ref', hue='estado_civil', data=df)

labels = ax.set_xticklabels(tick_labs)

plt.legend(bbox_to_anchor = (1.05, 1), loc = 2, borderaxespad = 0);

# %%
plt.figure(figsize=(15,6))

ax = sns.countplot(x='data_ref', hue='tipo_residencia', data=df)

labels = ax.set_xticklabels(tick_labs)

plt.legend(bbox_to_anchor = (1.05, 1), loc = 2, borderaxespad = 0);

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
plt.figure(figsize=(14,5))

ax = sns.pointplot(x='data_ref', y='renda', hue = 'sexo', data=df, dodge=True, ci=95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.3), ncol = 3)

labels = ax.set_xticklabels(tick_labs);

# %%
plt.figure(figsize=(14,5))

ax = sns.pointplot(x='data_ref', y='renda', hue = 'tipo_renda', data=df, dodge=True, ci=95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.3), ncol = 3)

labels = ax.set_xticklabels(tick_labs);

# %%
plt.figure(figsize=(14,5))

ax = sns.pointplot(x='data_ref', y='renda', hue = 'educacao', data=df, dodge=True, ci=95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.3), ncol = 3)

labels = ax.set_xticklabels(tick_labs);

# %%
plt.figure(figsize=(14,5))

ax = sns.pointplot(x='data_ref', y='renda', hue = 'tipo_residencia', data=df, dodge=True, ci=95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.3), ncol = 3)

labels = ax.set_xticklabels(tick_labs);

# %%
plt.figure(figsize=(14,5))

ax = sns.pointplot(x='data_ref', y='renda', hue = 'estado_civil', data=df, dodge=True, ci=95)

plt.legend(loc = 'lower center', bbox_to_anchor=(0.5, -.3), ncol = 3)

labels = ax.set_xticklabels(tick_labs);

# %% [markdown]
# ### Análise das variáveis:
#
# #### tipo_residencia:
# com mudanças significativas ao longo do tempo, não serviria para nossa modelagem;
#
# #### estado_civil:
# com um padrão de oscilações, poderia ser uma boa variável para nossa modelagem;
#
# #### tipo_renda:
# também pode ser uma boa para nossa modelagem, talvez tratando os dados das pessoas bolsistas por ser discrepante;
#
# #### sexo:
# não há mudanças significativas;
#
# #### educacao:
# muitas mudanças ao longo do tempo. Não serviria.
